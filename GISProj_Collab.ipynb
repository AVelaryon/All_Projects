# %% [markdown]
# <a href="https://colab.research.google.com/github/AVelaryon/All_Projects/blob/main/GISProj_Collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import re
import requests as req
import matplotlib.pyplot as plt
import pandas as pd
from sodapy import Socrata

# %%
#FOUND API. no need for requests
# requ_url = 'https://www.dot.ny.gov/portal/pls/portal/MEXIS_APP.DYN_PROJECT_DETAILS.show'
# req_post = {'p_arg_names': 'p_pin', 'p_arg_values':801079}
# # resp = req.get(requ_url)
# def data_retrieval(url: str, key: list[str]) -> pd.DataFrame:
#     response = req.get(url)
#     if response.ok == True and response.status_code == 200:
#         print('Success')
#     else:
#         print('Failed')
#     data = response.json()
#     return data
# response = req.get(requ_url, params=req_post)
# print(response.text)

# %%
client = Socrata("data.ny.gov",app_token='SUV6CnpKWErb1fdYcxWDEXpHl', username='dwightdinkins@gmail.com',password='AVelaryon@2134')
results = client.get("rz8t-4kmq", limit=5000)
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#      major_pin contract_number            region  \
# 0       000616         D263845    10 LONG ISLAND
# 1       000822             NaN    10 LONG ISLAND
# 2       000823             NaN    10 LONG ISLAND
# 3       001145         D264139    10 LONG ISLAND
# 4       001627         D263744    10 LONG ISLAND
# ...        ...             ...               ...
# 1932    XM2402             NaN  11 NEW YORK CITY
# 1933    XM2460             NaN  11 NEW YORK CITY
# 1934    XM2521             NaN  11 NEW YORK CITY
# 1935    XM2730             NaN  11 NEW YORK CITY
# 1936    XM2748             NaN  11 NEW YORK CITY
#
#                                           project_title  \
# 0                   OP SHARED USE PATH TOBAY TO CAPTREE
# 1                South Ferry Dock at NY114 Improvements
# 2     NY114 Pavement Resurfacing Stephen Hands Path ...
# 3           NY231 LAKE TO I495 CONCRETE PAVEMENT REPAIR
# 4                        NY112 RECONS I495 TO GRANNY RD
# ...                                                 ...
# 1932       REGIONAL BRIDGE WASHING, ALL COUNTIES IN NYC
# 1933  RETAINING WALLS INSPECTION AND CORRECTIVE MAIN...
# 1934  WHERE AND WHEN BRIDGE STEEL REPAIRS, ALL COUNT...
# 1935  PAVEMENT PRESERVATION - CRACKS AND JOINTS SEAL...
# 1936                      ASPHALT PAVEMENT PRESERVATION
#
#                                          project_status              status  \
# 0     Construction of 3rd phase of 14 mile shared-us...   Completed Project
# 1     Improve South Ferry Dock at NY114 including re...      In Development
# 2     NY114 Pavement Resurfacing from Stephen Hands ...      In Development
# 3     Concrete Pavement repair including joint seali...  Under Construction
# 4     Reconstruction of NY112 between I495 and Grann...  Under Construction
# ...                                                 ...                 ...
# 1932  Regional bridge washing, all counties in New Y...  Future Development
# 1933  The objectives of this project are to ensure p...  Future Development
# 1934  Perform emergency steel repairs to maintain st...  Future Development
# 1935  PREVENTIVE MAINTENANCE OF PAVMENT BY FILLING &...  Future Development
# 1936  ASPHALT PAVEMENT PRESERVATION ON STATE HIGHWAY...  Future Development
#
#       bid_opening_date federal_funding state_funding local_funding  ...  \
# 0           04/17/2019             Yes           Yes            No  ...
# 1          Summer 2022             Yes           Yes            No  ...
# 2          Summer 2021             Yes           Yes            No  ...
# 3           01/09/2020             Yes           Yes            No  ...
# 4           06/21/2018             Yes           Yes            No  ...
# ...                ...             ...           ...           ...  ...
# 1932         Fall 2024             Yes           Yes            No  ...
# 1933         Fall 2024             Yes           Yes            No  ...
# 1934         Fall 2024              No           Yes            No  ...
# 1935  Winter 2026/2027              No           Yes            No  ...
# 1936         Fall 2026              No           Yes            No  ...
#
#      contract_award_amount approved_cost_changes current_award_amount  \
# 0                 16193713            1387827.44          17581540.44
# 1                      NaN                   NaN                  NaN
# 2                      NaN                   NaN                  NaN
# 3                  4560000             283654.94           4843654.94
# 4                 32687178            -1029161.6           31658016.4
# ...                    ...                   ...                  ...
# 1932                   NaN                   NaN                  NaN
# 1933                   NaN                   NaN                  NaN
# 1934                   NaN                   NaN                  NaN
# 1935                   NaN                   NaN                  NaN
# 1936                   NaN                   NaN                  NaN
#
#      estimated_or_actual_completed_date schedule_performance cost_performance  \
# 0               2020-11-25T00:00:00.000                GREEN           YELLOW
# 1                                   NaN                  NaN              NaN
# 2                                   NaN                  NaN              NaN
# 3               2021-07-06T00:00:00.000                GREEN           YELLOW
# 4               2021-09-30T00:00:00.000               YELLOW            GREEN
# ...                                 ...                  ...              ...
# 1932                                NaN                  NaN              NaN
# 1933                                NaN                  NaN              NaN
# 1934                                NaN                  NaN              NaN
# 1935                                NaN                  NaN              NaN
# 1936                                NaN                  NaN              NaN
#
#      in_future_development_start_date construction_start_date  \
# 0                                 NaN                     NaN
# 1                         Spring 2020             Summer 2022
# 2                         Spring 2020               Fall 2021
# 3                           Fall 2018                     NaN
# 4                           Fall 2014                     NaN
# ...                               ...                     ...
# 1932                      Summer 2023        Winter 2024/2025
# 1933                      Spring 2021               Fall 2024
# 1934                 Winter 2022/2023        Winter 2024/2025
# 1935                              NaN        Winter 2026/2027
# 1936                              NaN        Winter 2026/2027
#
#      construction_end_date construction_amount
# 0                      NaN                 NaN
# 1              Summer 2023             3100000
# 2         Winter 2022/2023             9600000
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ...                    ...                 ...
# 1932           Spring 2025             4200000
# 1933      Winter 2026/2027             5000000
# 1934           Summer 2027            10000000
# 1935                   NaN             2200000
# 1936                   NaN            22000000
#
# [1937 rows x 23 columns]

# %%
group_status = results_df.groupby(by='status', as_index=False)
indx = (results_df.status.str.contains('Completed Project', regex=False).to_numpy() == 1).nonzero()

# %%
pd.set_option('display.max_columns', 23)

# %%
completed = results_df.iloc[indx[0],:].copy()
completed
# indx
# Out:
#      major_pin contract_number            region  \
# 0       000616         D263845    10 LONG ISLAND
# 17      005927         D263713    10 LONG ISLAND
# 20      011260         D263735    10 LONG ISLAND
# 21      012112         D263907    10 LONG ISLAND
# 29      033915         D264032    10 LONG ISLAND
# ...        ...             ...               ...
# 1900    XM1850         D264063  11 NEW YORK CITY
# 1903    XM1860         D263918  11 NEW YORK CITY
# 1904    XM1921         D263839  11 NEW YORK CITY
# 1905    XM1922         D263809  11 NEW YORK CITY
# 1908    XM1949         D263994  11 NEW YORK CITY
#
#                                           project_title  \
# 0                   OP SHARED USE PATH TOBAY TO CAPTREE
# 17                NY27 OAKDALE MERGE INTERCHANGE IMPVTS
# 20                 NY110 PEDESTRIAN SAFETY IMPROVEMENTS
# 21       NY106 CONC PAVMT REPAIR NY24 TO OLD COUNTRY RD
# 29                     SMSP GUIDERAIL REHAB I495 TO END
# ...                                                 ...
# 1900                 ADA REQUIREMENTS IN BRONX CO., NYC
# 1903  CORRECTIVE & PREVENTIVE MAINTENANCE OF RETAINI...
# 1904  WHERE AND WHEN BRIDGE STEEL REPAIRS, ALL COUNT...
# 1905  CORRECTIVE MAINTENANCE REPAIR CONTRACT (NSCO),...
# 1908  CONCRETE PAVEMENT PRESERVATION, KINGS AND NEW ...
#
#                                          project_status             status  \
# 0     Construction of 3rd phase of 14 mile shared-us...  Completed Project
# 17    NY27 Oakdale Merge Interchange Impvts - resurf...  Completed Project
# 20    Pedestrian safety improvements along  NY110 be...  Completed Project
# 21    CONCRETE PAVEMENT REPAIRS ON NY106 FROM NY24 T...  Completed Project
# 29    REPAIR AND REPLACE GUIDERAIL SECTIONS SUNKEN M...  Completed Project
# ...                                                 ...                ...
# 1900  Build curb ramps, crosswalks and sidewalks at ...  Completed Project
# 1903  CORRECTIVE AND REVENTIVE MAINTENANCE  OF MASON...  Completed Project
# 1904  Perform emergency steel repairs to maintain st...  Completed Project
# 1905  Address NSCO, flags & other conditions on brid...  Completed Project
# 1908  Concrete Pavement  preservation on Rt. 9A from...  Completed Project
#
#      bid_opening_date federal_funding state_funding local_funding  \
# 0          04/17/2019             Yes           Yes            No
# 17         06/07/2018              No           Yes           Yes
# 20         06/07/2018             Yes           Yes            No
# 21         03/14/2019             Yes           Yes            No
# 29         09/12/2019             Yes           Yes            No
# ...               ...             ...           ...           ...
# 1900       11/21/2019             Yes           Yes            No
# 1903       03/28/2019             Yes           Yes            No
# 1904       11/29/2018              No           Yes            No
# 1905       12/13/2018              No           Yes            No
# 1908       06/20/2019              No           Yes            No
#
#                                       type_of_work  \
# 0                  Bicycle Facility (Highway): New
# 17                         Pavement: Mill and Fill
# 20    Pedestrian Facility (Highway): Improve/Rehab
# 21       Pavement: Concrete Pavement Repair, Heavy
# 29         Guiderail/Median Barrier: Rehab/Improve
# ...                                            ...
# 1900  Pedestrian Facility (Highway): Improve/Rehab
# 1903             Retaining Wall: New/Improve/Rehab
# 1904              Emergency Response Bridge Repair
# 1905              Emergency Response Bridge Repair
# 1908     Pavement: Concrete Pavement Repair, Heavy
#
#                             public_friendly_description  \
# 0     Project proposes to construct the 3rd phase of...
# 17    This project is located at the Oakdale Merge, ...
# 20    This project proposes to provide upgraded pede...
# 21    This project proposes to provide concrete pave...
# 29    This project proposes to replace existing the ...
# ...                                                 ...
# 1900  This project will build (either throught repla...
# 1903  This project will repair and restore brick, st...
# 1904  This project will perform emergency steel repa...
# 1905  This project will perform maintenance repairs ...
# 1908  This project will perform preservation of the ...
#
#           contract_award_date contract_award_amount approved_cost_changes  \
# 0     2019-07-12T00:00:00.000              16193713            1387827.44
# 17    2018-08-16T00:00:00.000             7281160.4             357766.98
# 20    2018-07-23T00:00:00.000            3980019.75             459342.64
# 21    2019-04-25T00:00:00.000            6820426.55             161953.24
# 29    2019-11-06T00:00:00.000             4464797.2                218.09
# ...                       ...                   ...                   ...
# 1900  2020-01-08T00:00:00.000              874049.9             -282679.6
# 1903  2019-06-25T00:00:00.000           14199865.45            -575172.71
# 1904  2019-01-17T00:00:00.000              10555555            -690065.36
# 1905  2019-04-16T00:00:00.000              26680095            1113136.22
# 1908  2019-08-02T00:00:00.000              10141000           -1250148.21
#
#      current_award_amount estimated_or_actual_completed_date  \
# 0             17581540.44            2020-11-25T00:00:00.000
# 17             7638927.38            2020-09-14T00:00:00.000
# 20             4439362.39            2020-09-18T00:00:00.000
# 21             6982379.79            2020-12-10T00:00:00.000
# 29             4465015.29            2021-06-18T00:00:00.000
# ...                   ...                                ...
# 1900             591370.3            2020-10-08T00:00:00.000
# 1903          13624692.74            2020-11-17T00:00:00.000
# 1904           9865489.64            2021-01-19T00:00:00.000
# 1905          27793231.22            2020-10-19T00:00:00.000
# 1908           8890851.79            2020-12-02T00:00:00.000
#
#      schedule_performance cost_performance in_future_development_start_date  \
# 0                   GREEN           YELLOW                              NaN
# 17                    RED            GREEN                      Spring 2017
# 20                    RED              RED                      Summer 2016
# 21                    RED            GREEN                 Winter 2016/2017
# 29                  GREEN            GREEN                      Summer 2017
# ...                   ...              ...                              ...
# 1900                GREEN            GREEN                        Fall 2018
# 1903                GREEN            GREEN                      Summer 2015
# 1904                GREEN            GREEN                      Spring 2018
# 1905                  RED            GREEN                      Spring 2018
# 1908                GREEN            GREEN                      Summer 2018
#
#      construction_start_date construction_end_date construction_amount
# 0                        NaN                   NaN                 NaN
# 17                       NaN                   NaN                 NaN
# 20                       NaN                   NaN                 NaN
# 21                       NaN                   NaN                 NaN
# 29                       NaN                   NaN                 NaN
# ...                      ...                   ...                 ...
# 1900                     NaN                   NaN                 NaN
# 1903                     NaN                   NaN                 NaN
# 1904                     NaN                   NaN                 NaN
# 1905                     NaN                   NaN                 NaN
# 1908                     NaN                   NaN                 NaN
#
# [291 rows x 23 columns]

# %%
# Converting COntrct Award Date to Datetime Object
completed.contract_award_date = pd.to_datetime(completed.contract_award_date)
completed.estimated_or_actual_completed_date = pd.to_datetime(completed.estimated_or_actual_completed_date)
completed
# Out:
#      major_pin contract_number            region  \
# 0       000616         D263845    10 LONG ISLAND
# 17      005927         D263713    10 LONG ISLAND
# 20      011260         D263735    10 LONG ISLAND
# 21      012112         D263907    10 LONG ISLAND
# 29      033915         D264032    10 LONG ISLAND
# ...        ...             ...               ...
# 1900    XM1850         D264063  11 NEW YORK CITY
# 1903    XM1860         D263918  11 NEW YORK CITY
# 1904    XM1921         D263839  11 NEW YORK CITY
# 1905    XM1922         D263809  11 NEW YORK CITY
# 1908    XM1949         D263994  11 NEW YORK CITY
#
#                                           project_title  \
# 0                   OP SHARED USE PATH TOBAY TO CAPTREE
# 17                NY27 OAKDALE MERGE INTERCHANGE IMPVTS
# 20                 NY110 PEDESTRIAN SAFETY IMPROVEMENTS
# 21       NY106 CONC PAVMT REPAIR NY24 TO OLD COUNTRY RD
# 29                     SMSP GUIDERAIL REHAB I495 TO END
# ...                                                 ...
# 1900                 ADA REQUIREMENTS IN BRONX CO., NYC
# 1903  CORRECTIVE & PREVENTIVE MAINTENANCE OF RETAINI...
# 1904  WHERE AND WHEN BRIDGE STEEL REPAIRS, ALL COUNT...
# 1905  CORRECTIVE MAINTENANCE REPAIR CONTRACT (NSCO),...
# 1908  CONCRETE PAVEMENT PRESERVATION, KINGS AND NEW ...
#
#                                          project_status             status  \
# 0     Construction of 3rd phase of 14 mile shared-us...  Completed Project
# 17    NY27 Oakdale Merge Interchange Impvts - resurf...  Completed Project
# 20    Pedestrian safety improvements along  NY110 be...  Completed Project
# 21    CONCRETE PAVEMENT REPAIRS ON NY106 FROM NY24 T...  Completed Project
# 29    REPAIR AND REPLACE GUIDERAIL SECTIONS SUNKEN M...  Completed Project
# ...                                                 ...                ...
# 1900  Build curb ramps, crosswalks and sidewalks at ...  Completed Project
# 1903  CORRECTIVE AND REVENTIVE MAINTENANCE  OF MASON...  Completed Project
# 1904  Perform emergency steel repairs to maintain st...  Completed Project
# 1905  Address NSCO, flags & other conditions on brid...  Completed Project
# 1908  Concrete Pavement  preservation on Rt. 9A from...  Completed Project
#
#      bid_opening_date federal_funding state_funding local_funding  \
# 0          04/17/2019             Yes           Yes            No
# 17         06/07/2018              No           Yes           Yes
# 20         06/07/2018             Yes           Yes            No
# 21         03/14/2019             Yes           Yes            No
# 29         09/12/2019             Yes           Yes            No
# ...               ...             ...           ...           ...
# 1900       11/21/2019             Yes           Yes            No
# 1903       03/28/2019             Yes           Yes            No
# 1904       11/29/2018              No           Yes            No
# 1905       12/13/2018              No           Yes            No
# 1908       06/20/2019              No           Yes            No
#
#                                       type_of_work  \
# 0                  Bicycle Facility (Highway): New
# 17                         Pavement: Mill and Fill
# 20    Pedestrian Facility (Highway): Improve/Rehab
# 21       Pavement: Concrete Pavement Repair, Heavy
# 29         Guiderail/Median Barrier: Rehab/Improve
# ...                                            ...
# 1900  Pedestrian Facility (Highway): Improve/Rehab
# 1903             Retaining Wall: New/Improve/Rehab
# 1904              Emergency Response Bridge Repair
# 1905              Emergency Response Bridge Repair
# 1908     Pavement: Concrete Pavement Repair, Heavy
#
#                             public_friendly_description contract_award_date  \
# 0     Project proposes to construct the 3rd phase of...          2019-07-12
# 17    This project is located at the Oakdale Merge, ...          2018-08-16
# 20    This project proposes to provide upgraded pede...          2018-07-23
# 21    This project proposes to provide concrete pave...          2019-04-25
# 29    This project proposes to replace existing the ...          2019-11-06
# ...                                                 ...                 ...
# 1900  This project will build (either throught repla...          2020-01-08
# 1903  This project will repair and restore brick, st...          2019-06-25
# 1904  This project will perform emergency steel repa...          2019-01-17
# 1905  This project will perform maintenance repairs ...          2019-04-16
# 1908  This project will perform preservation of the ...          2019-08-02
#
#      contract_award_amount approved_cost_changes current_award_amount  \
# 0                 16193713            1387827.44          17581540.44
# 17               7281160.4             357766.98           7638927.38
# 20              3980019.75             459342.64           4439362.39
# 21              6820426.55             161953.24           6982379.79
# 29               4464797.2                218.09           4465015.29
# ...                    ...                   ...                  ...
# 1900              874049.9             -282679.6             591370.3
# 1903           14199865.45            -575172.71          13624692.74
# 1904              10555555            -690065.36           9865489.64
# 1905              26680095            1113136.22          27793231.22
# 1908              10141000           -1250148.21           8890851.79
#
#      estimated_or_actual_completed_date schedule_performance cost_performance  \
# 0                            2020-11-25                GREEN           YELLOW
# 17                           2020-09-14                  RED            GREEN
# 20                           2020-09-18                  RED              RED
# 21                           2020-12-10                  RED            GREEN
# 29                           2021-06-18                GREEN            GREEN
# ...                                 ...                  ...              ...
# 1900                         2020-10-08                GREEN            GREEN
# 1903                         2020-11-17                GREEN            GREEN
# 1904                         2021-01-19                GREEN            GREEN
# 1905                         2020-10-19                  RED            GREEN
# 1908                         2020-12-02                GREEN            GREEN
#
#      in_future_development_start_date construction_start_date  \
# 0                                 NaN                     NaN
# 17                        Spring 2017                     NaN
# 20                        Summer 2016                     NaN
# 21                   Winter 2016/2017                     NaN
# 29                        Summer 2017                     NaN
# ...                               ...                     ...
# 1900                        Fall 2018                     NaN
# 1903                      Summer 2015                     NaN
# 1904                      Spring 2018                     NaN
# 1905                      Spring 2018                     NaN
# 1908                      Summer 2018                     NaN
#
#      construction_end_date construction_amount
# 0                      NaN                 NaN
# 17                     NaN                 NaN
# 20                     NaN                 NaN
# 21                     NaN                 NaN
# 29                     NaN                 NaN
# ...                    ...                 ...
# 1900                   NaN                 NaN
# 1903                   NaN                 NaN
# 1904                   NaN                 NaN
# 1905                   NaN                 NaN
# 1908                   NaN                 NaN
#
# [291 rows x 23 columns]
